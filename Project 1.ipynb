# %%
#load csv file
import pandas as pd
df=pd.read_csv("datasets/DC_Properties.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL  ...  LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0  ... -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0  ... -77.040764       Old City 2   040 D Old City 2
# 2  1910.0   2009.0  ... -77.040678       Old City 2   040 D Old City 2
# 3  1900.0   2003.0  ... -77.040629       Old City 2   040 D Old City 2
# 4  1913.0   2012.0  ... -77.039361       Old City 2   040 D Old City 2
#
#    CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE          X          Y QUADRANT
# ...

# %%
df.tail()
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 158952      158952       1          0  Forced Air  Y        NaN      3      1
# 158953      158953       1          0  Forced Air  Y        NaN      4      2
# 158954      158954       2          0  Forced Air  Y        NaN      4      2
# 158955      158955       1          0   Warm Cool  Y        NaN      2      0
# 158956      158956       1          0   Warm Cool  Y        NaN      2      0
#
#            AYB  YR_RMDL  ...  LONGITUDE       ASSESSMENT_NBHD  \
# 158952  1938.0   2006.0  ...  -77.01942            Old City 2
# 158953  1938.0   2006.0  ...  -77.01942            Old City 2
# 158954  1920.0   2007.0  ...  -77.01942            Old City 2
# 158955  1965.0      NaN  ...  -77.01823  Southwest Waterfront
# 158956  1965.0      NaN  ...  -77.01823  Southwest Waterfront
#
#        ASSESSMENT_SUBNBHD  CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
df.count()
# Out:
# Unnamed: 0            158957
# BATHRM                158957
# HF_BATHRM             158957
# HEAT                  158957
# AC                    158957
# NUM_UNITS             106696
# ROOMS                 158957
# BEDRM                 158957
# AYB                   158686
# YR_RMDL                80928
# EYB                   158957
# STORIES               106652
# SALEDATE              132187
# PRICE                  98216
# QUALIFIED             158957
# SALE_NUM              158957
# GBA                   106696
# BLDG_NUM              158957
# STYLE                 106696
# STRUCT                106696
# GRADE                 106696
# CNDTN                 106696
# EXTWALL               106696
# ROOF                  106696
# INTWALL               106696
# KITCHENS              106695
# FIREPLACES            158957
# USECODE               158957
# LANDAREA              158957
# GIS_LAST_MOD_DTTM     158957
# SOURCE                158957
# CMPLX_NUM              52261
# ...

# %%
#Analyze "Bedrooms"
df['ROOMS'].max()
# Out:
# 48

# %%
df['ROOMS'].min()
# Out:
# 0

# %%
df['ROOMS'].sum()
# Out:
# 983584

# %%
df['ROOMS'].mean()
# Out:
# 6.187736306045031

# %%
df['ROOMS'].median()
# Out:
# 6.0

# %%
df['ROOMS'].mode()
# Out:
# 0    6
# dtype: int64

# %%
df['ROOMS'].value_counts()
# Out:
# 6     37259
# 7     22338
# 4     20593
# 3     17759
# 5     16852
# 8     16327
# 9      7616
# 10     5909
# 2      5294
# 12     2929
# 11     2364
# 16     1346
# 13      766
# 14      595
# 15      310
# 20      148
# 0       138
# 18      124
# 1        96
# 17       77
# 19       41
# 21       20
# 22       10
# 23       10
# 24       10
# 25        6
# 28        5
# 27        2
# 39        2
# 41        1
# 34        1
# 40        1
# 37        1
# 35        1
# 29        1
# 32        1
# 31        1
# 30        1
# 26        1
# 48        1
# Name: ROOMS, dtype: int64

# %%
df['ROOMS'].std()
# Out:
# 2.618164876300674

# %%
#descriptive statsistics
df.describe()
# Out:
#           Unnamed: 0         BATHRM      HF_BATHRM      NUM_UNITS  \
# count  158957.000000  158957.000000  158957.000000  106696.000000
# mean    79478.000000       1.810678       0.458237       1.198039
# std     45887.077707       0.976396       0.587571       0.596924
# min         0.000000       0.000000       0.000000       0.000000
# 25%     39739.000000       1.000000       0.000000       1.000000
# 50%     79478.000000       2.000000       0.000000       1.000000
# 75%    119217.000000       2.000000       1.000000       1.000000
# max    158956.000000      14.000000      11.000000       6.000000
#
#                ROOMS          BEDRM            AYB       YR_RMDL  \
# count  158957.000000  158957.000000  158686.000000  80928.000000
# mean        6.187736       2.732506    1941.987579   1998.243537
# std         2.618165       1.358864      33.640234     16.575786
# min         0.000000       0.000000    1754.000000     20.000000
# ...

# %%
df['BEDRM'].groupby(df['ZIPCODE']).mean()
# Out:
# ZIPCODE
# 20001.0    2.515594
# 20002.0    2.898774
# 20003.0    2.767187
# 20004.0    1.208872
# 20005.0    1.375147
# 20006.0    0.220339
# 20007.0    2.901429
# 20008.0    2.824291
# 20009.0    2.101359
# 20010.0    3.019757
# 20011.0    3.216365
# 20012.0    3.359883
# 20015.0    3.450628
# 20016.0    2.903138
# 20017.0    3.021700
# 20018.0    3.103704
# 20019.0    2.823728
# 20020.0    2.823355
# 20024.0    1.550725
# 20032.0    2.862845
# 20036.0    1.044926
# 20037.0    1.319035
# 20052.0    3.947368
# 20392.0    1.241935
# Name: BEDRM, dtype: float64

# %%
df[['BEDRM','BATHRM']].groupby(df['ZIPCODE']).mean()
# Out:
#             BEDRM    BATHRM
# ZIPCODE
# 20001.0  2.515594  1.752109
# 20002.0  2.898774  1.807051
# 20003.0  2.767187  1.877355
# 20004.0  1.208872  1.260628
# 20005.0  1.375147  1.433608
# 20006.0  0.220339  1.025424
# 20007.0  2.901429  2.229815
# 20008.0  2.824291  2.264961
# 20009.0  2.101359  1.677625
# 20010.0  3.019757  1.877411
# 20011.0  3.216365  1.763760
# 20012.0  3.359883  2.050753
# 20015.0  3.450628  2.356193
# 20016.0  2.903138  2.205656
# 20017.0  3.021700  1.677873
# 20018.0  3.103704  1.756790
# 20019.0  2.823728  1.571279
# 20020.0  2.823355  1.575931
# 20024.0  1.550725  1.441868
# 20032.0  2.862845  1.662884
# 20036.0  1.044926  1.284355
# 20037.0  1.319035  1.422788
# 20052.0  3.947368  1.894737
# 20392.0  1.241935  1.295699

# %%
pd.pivot_table(df,index=['ZIPCODE'])
# Out:
#                  AYB    BATHRM     BEDRM  BLDG_NUM  CENSUS_TRACT    CMPLX_NUM  \
# ZIPCODE
# 20001.0  1944.296908  1.752109  2.515594  1.000569   4426.667457  3075.659109
# 20002.0  1924.439656  1.807051  2.898774  1.000307   8574.291723  3202.751887
# 20003.0  1927.502625  1.877355  2.767187  1.000624   6845.625702  3056.194976
# 20004.0  1999.966728  1.260628  1.208872  1.000000   5800.000000  3065.667283
# 20005.0  1959.517920  1.433608  1.375147  1.000000   5681.060223  2648.242929
# 20006.0  1959.491525  1.025424  0.220339  1.000000  10800.000000  2025.000000
# 20007.0  1936.747423  2.229815  2.901429  1.001661    384.865766  2410.201071
# 20008.0  1940.429981  2.264961  2.824291  1.001323   1399.151889  1563.928487
# 20009.0  1932.782506  1.677625  2.101359  1.000152   4126.949283  2156.422629
# 20010.0  1922.907676  1.877411  3.019757  1.000000   2900.932638  2570.695490
# 20011.0  1933.187243  1.763760  3.216365  1.000183   3541.576994  3125.653263
# ...

# %%
pd.pivot_table(df,values=['LANDAREA'],index=['ZIPCODE'])
# Out:
#             LANDAREA
# ZIPCODE
# 20001.0   936.046260
# 20002.0  1434.204598
# 20003.0  1275.112414
# 20004.0   100.548983
# 20005.0   337.052291
# 20006.0   118.694915
# 20007.0  2854.486433
# 20008.0  4248.028231
# 20009.0   773.433225
# 20010.0  1519.992066
# 20011.0  2823.202789
# 20012.0  5641.328800
# 20015.0  5425.876522
# 20016.0  4456.139985
# 20017.0  3187.304340
# 20018.0  3994.134744
# 20019.0  3061.811045
# 20020.0  3161.729322
# 20024.0   834.436715
# 20032.0  2730.820387
# 20036.0   269.978858
# 20037.0   304.740483
# 20052.0  1320.789474
# 20392.0   262.844086

# %%
df['STORIES'].unique()
# Out:
# array([3.00e+00, 4.00e+00, 2.00e+00, 2.50e+00, 2.25e+00, 3.50e+00,
#        1.00e+00,      nan, 3.25e+00, 1.50e+00, 2.75e+00, 7.00e+00,
#        6.50e+01, 2.70e+00, 0.00e+00, 8.26e+02, 6.00e+00, 2.30e+00,
#        5.00e+00, 2.20e+00, 3.70e+00, 1.70e+00, 3.20e+00, 1.75e+00,
#        3.75e+00, 4.50e+00, 2.50e+02, 2.75e+02, 1.25e+00, 2.50e+01,
#        4.75e+00, 9.00e+00, 5.00e-01, 8.25e+00, 7.50e-01, 2.33e+00,
#        2.00e+01, 1.20e+01, 4.30e+01, 1.34e+00, 2.50e-01])

# %%
#Finding total missing values
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# BATHRM                     0
# HF_BATHRM                  0
# HEAT                       0
# AC                         0
# NUM_UNITS              52261
# ROOMS                      0
# BEDRM                      0
# AYB                      271
# YR_RMDL                78029
# EYB                        0
# STORIES                52305
# SALEDATE               26770
# PRICE                  60741
# QUALIFIED                  0
# SALE_NUM                   0
# GBA                    52261
# BLDG_NUM                   0
# STYLE                  52261
# STRUCT                 52261
# GRADE                  52261
# CNDTN                  52261
# EXTWALL                52261
# ROOF                   52261
# INTWALL                52261
# KITCHENS               52262
# FIREPLACES                 0
# USECODE                    0
# LANDAREA                   0
# GIS_LAST_MOD_DTTM          0
# SOURCE                     0
# CMPLX_NUM             106696
# ...

# %%
#Finding missing values in 'Price'
missing=df['PRICE'].isnull()
df.loc[missing]
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 1                1       3          1      Warm Cool  Y        2.0     11
# 4                4       2          1      Warm Cool  Y        1.0     11
# 6                6       1          0      Warm Cool  Y        2.0      5
# 9                9       1          1  Hot Water Rad  Y        1.0      6
# 10              10       3          0     Forced Air  N        3.0     12
# 11              11       5          0  Hot Water Rad  Y        3.0     16
# 12              12       2          0  Hot Water Rad  N        2.0      9
# 13              13       2          0      Warm Cool  Y        2.0     11
# 15              15       2          1      Warm Cool  Y        2.0      9
# 17              17       2          0  Hot Water Rad  N        1.0      6
# 18              18       3          1  Hot Water Rad  Y        2.0     10
# 21              21       3          0     Forced Air  Y        2.0     12
# ...

# %%
df_null=df.isnull()
df[df_null]
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM HEAT   AC  NUM_UNITS  ROOMS  BEDRM  AYB  \
# 0              NaN     NaN        NaN  NaN  NaN        NaN    NaN    NaN  NaN
# 1              NaN     NaN        NaN  NaN  NaN        NaN    NaN    NaN  NaN
# 2              NaN     NaN        NaN  NaN  NaN        NaN    NaN    NaN  NaN
# 3              NaN     NaN        NaN  NaN  NaN        NaN    NaN    NaN  NaN
# 4              NaN     NaN        NaN  NaN  NaN        NaN    NaN    NaN  NaN
# 5              NaN     NaN        NaN  NaN  NaN        NaN    NaN    NaN  NaN
# 6              NaN     NaN        NaN  NaN  NaN        NaN    NaN    NaN  NaN
# 7              NaN     NaN        NaN  NaN  NaN        NaN    NaN    NaN  NaN
# 8              NaN     NaN        NaN  NaN  NaN        NaN    NaN    NaN  NaN
# 9              NaN     NaN        NaN  NaN  NaN        NaN    NaN    NaN  NaN
# 10             NaN     NaN        NaN  NaN  NaN        NaN    NaN    NaN  NaN
# ...

# %%
df_complete=df.notnull()
df_complete.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM  HEAT    AC  NUM_UNITS  ROOMS  BEDRM   AYB  \
# 0        True    True       True  True  True       True   True   True  True
# 1        True    True       True  True  True       True   True   True  True
# 2        True    True       True  True  True       True   True   True  True
# 3        True    True       True  True  True       True   True   True  True
# 4        True    True       True  True  True       True   True   True  True
#
#    YR_RMDL  ...  LONGITUDE  ASSESSMENT_NBHD  ASSESSMENT_SUBNBHD  CENSUS_TRACT  \
# 0     True  ...       True             True                True          True
# 1     True  ...       True             True                True          True
# 2     True  ...       True             True                True          True
# 3     True  ...       True             True                True          True
# 4     True  ...       True             True                True          True
#
# ...

# %%
#Drop the rows without data
df_no_missing=df[df_complete]

# %%
df_no_missing
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 1                1       3          1      Warm Cool  Y        2.0     11
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 4                4       2          1      Warm Cool  Y        1.0     11
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 6                6       1          0      Warm Cool  Y        2.0      5
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 9                9       1          1  Hot Water Rad  Y        1.0      6
# 10              10       3          0     Forced Air  N        3.0     12
# 11              11       5          0  Hot Water Rad  Y        3.0     16
# ...

# %%
df_no_missing.sort_values('BEDRM')
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM            HEAT AC  NUM_UNITS  ROOMS  \
# 158956      158956       1          0       Warm Cool  Y        NaN      2
# 100386      100386       1          0   Hot Water Rad  N        1.0      0
# 124045      124045       1          0         Ht Pump  Y        NaN      2
# 124032      124032       1          0         Ht Pump  Y        NaN      2
# 124023      124023       1          0         Ht Pump  N        NaN      2
# 124020      124020       1          0         Ht Pump  N        NaN      2
# 123983      123983       1          0         Ht Pump  Y        NaN      2
# 100665      100665       1          0   Hot Water Rad  N        1.0      0
# 123972      123972       1          0         Ht Pump  Y        NaN      2
# 123956      123956       1          0         Ht Pump  Y        NaN      2
# 101196      101196       1          0   Hot Water Rad  N        1.0      0
# ...

# %%
#Binning data
bins=[0,4,8,12]
size_rooms=['small','medium','large']
df_no_missing['sizeofrooms']=pd.cut(df_no_missing['ROOMS'],bins,labels=size_rooms)
df_no_missing.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL  ...  ASSESSMENT_NBHD  ASSESSMENT_SUBNBHD CENSUS_TRACT  \
# 0  1910.0   1988.0  ...       Old City 2    040 D Old City 2       4201.0
# 1  1898.0   2007.0  ...       Old City 2    040 D Old City 2       4201.0
# 2  1910.0   2009.0  ...       Old City 2    040 D Old City 2       4201.0
# 3  1900.0   2003.0  ...       Old City 2    040 D Old City 2       4201.0
# 4  1913.0   2012.0  ...       Old City 2    040 D Old City 2       4201.0
#
# ...
